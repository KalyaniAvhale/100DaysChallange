# %% [markdown]
# # Assignemnt : 14

# %% [markdown]
# #### 1. What does RGBA stand for?
#
# RGBA stands for red, blue, green and alpa . An RGBA value is a group of numbers that specify the amount of red, green, blue, and alpha (or transparency) in a color. Each of these component values is an integer from 0 (none at all) to 255 (the maximum)

# %% [markdown]
# #### 2. From the Pillow module, how do you get the RGBA value of any images?
# ImageColor.getcolor()

# %%
from PIL import Image
import matplotlib.pyplot as plt
filename = "panda.jpg"
img = Image.open(filename)
print(img.size)
display(img)
# Out:
# (191, 264)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=191x264 at 0x23BD6E82C40>

# %%
colors = img. getpixel((120,240)) #Get the RGB values at coordinate x = 120, y = 240.
print(colors)
# Out:
# (19, 15, 14)

# %% [markdown]
# #### 3. What is a box tuple, and how does it work?
# A box tuple is a tuple value of four integers: the left edge x-coordinate, the top edge y-coordinate, the width, and the height, respectively.Many of Pillow’s functions and methods take a box tuple argument. This means Pillow is expecting a tuple of four integer coordinates that represent a rectangular region in an image.

# %% [markdown]
# #### 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?
# Either of below options can be used,
# - image.size can be used after loading array in numpy format
# - PIL.Image.open() can be used to open image and then.width or .heigth can be used.
#
# Example :

# %%
p = Image.open('panda.jpg')

print(p.size)
#or
width, height = p.size

print(width)
print(height)
# Out:
# (191, 264)
# 191
# 264

# %% [markdown]
# #### 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
# imageObj.crop((0, 50, 50, 50)) will call this crop method as a box tuple to crop() Cropping an image means selecting a rectangular region inside an image and removing everything outside the rectangle. The crop() method on Image objects takes a box tuple and returns an Image object representing the cropped image.

# %% [markdown]
# #### 6. After making changes to an Image object, how could you save it as an image file?
# Call the imageObj.save('new_filename.png') method of the Image object to save it in an image file.

# %% [markdown]
# #### 7. What module contains Pillow’s shape-drawing code?
# The ImageDraw module contains code to draw on images.ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). They are returned by passing the Image object to the ImageDraw.Draw() function

# %% [markdown]
# #### 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
# ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). They are returned by passing the Image object to the ImageDraw.Draw() function
